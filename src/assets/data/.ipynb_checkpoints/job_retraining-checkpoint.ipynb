# %%
import pandas as pd

# %%
auto_df = pd.read_csv("automatability.csv").head()
relative_emp = pd.read_csv("relativeEmployment.csv").head()
similar_df = pd.read_csv("similarity.csv").head()
wagechange = pd.read_csv("wageChange.csv").head()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-11-47f8fc4c3b8f> in <module>()
#       2 relative_emp = pd.read_csv("relativeEmployment.csv").head()
#       3 similar_df = pd.read_csv("similarity.csv").head()
# ----> 4 wagechange = pd.read_csv("wageChange.csv.csv").head()
#
# ...

# %%
auto_df
# Out:
#                                           Unnamed: 0  Recreational Therapists  \
# 0                            Recreational Therapists                   0.0028
# 1  First-Line Supervisors of Mechanics, Installer...                   0.0028
# 2                     Emergency Management Directors                   0.0028
# 3   Mental Health and Substance Abuse Social Workers                   0.0028
# 4                                       Audiologists                   0.0028
#
#    First-Line Supervisors of Mechanics, Installers, and Repairers  \
# 0                                              0.003
# 1                                              0.003
# 2                                              0.003
# 3                                              0.003
# 4                                              0.003
#
#    Emergency Management Directors  \
# 0                           0.003
# 1                           0.003
# 2                           0.003
# ...
